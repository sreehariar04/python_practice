# %% [markdown]
# <a href="https://colab.research.google.com/github/sreehariar04/python_practice/blob/main/Sreehari_Pandas_CASE_STUDY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Case Study

# %% [markdown]
# **1) Import pandas, numpy**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **2) Load dataset using pd.read_csv()**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/IMDB-Movie-Data.csv')
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# **3) Display: shape, head, column names, datatypes, missing value**

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# **4) Check and remove duplicates**

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().any() # check if any duplicates present in the data frame.
# Out:
# np.False_

# %% [markdown]
# **5) Rename columns ("Title" > "Movie_Title")**

# %%
df1 = df.rename(columns={'Title':'Movie_Title'})
df1.head(2)
# Out:
#    Rank              Movie_Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0

# %% [markdown]
# **6) Get unique genres**

# %%
unique_genres = (
    df1['Genre']
    .str.split(',')        # split into lists
    .explode()             # turn lists into rows
    .str.strip()           # remove spaces
    .unique()              # get unique values
)
print(unique_genres)
# Out:
# ['Action' 'Adventure' 'Sci-Fi' 'Mystery' 'Horror' 'Thriller' 'Animation'
#  'Comedy' 'Family' 'Fantasy' 'Drama' 'Music' 'Biography' 'Romance'
#  'History' 'Crime' 'Western' 'War' 'Musical' 'Sport']

# %% [markdown]
# **7) Extract number of genres per movie**

# %%
df1['Genre_Count'] = df1['Genre'].apply(lambda x: len(x.split(',')))
df1.head(5)
# Out:
#    Rank              Movie_Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# 8.

# %% [markdown]
# **9) Top 5 movies by Rating**

# %%
df1.nlargest(5, 'Rating')
# Out:
#      Rank      Movie_Title                    Genre  \
# 54     55  The Dark Knight       Action,Crime,Drama
# 80     81        Inception  Action,Adventure,Sci-Fi
# 117   118           Dangal   Action,Biography,Drama
# 36     37     Interstellar   Adventure,Drama,Sci-Fi
# 96     97    Kimi no na wa  Animation,Drama,Fantasy
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 96   Two strangers find themselves linked in a biza...     Makoto Shinkai
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# ...

# %% [markdown]
# **10) Movies with highest/lowest revenue**

# %% [markdown]
# **Highest Revenue(Millions)**

# %%
df1.loc[df1['Revenue (Millions)'].idxmax(), ['Movie_Title', 'Revenue (Millions)']]
# Out:
# Movie_Title           Star Wars: Episode VII - The Force Awakens
# Revenue (Millions)                                        936.63
# Name: 50, dtype: object

# %% [markdown]
# **Lowest Revenue**

# %%
df1.loc[df1['Revenue (Millions)'].idxmin(), ['Movie_Title', 'Revenue (Millions)']]
# Out:
# Movie_Title           A Kind of Murder
# Revenue (Millions)                 0.0
# Name: 231, dtype: object

# %% [markdown]
# **11) Avg. rating by Director**

# %%
df1.groupby('Director')['Rating'].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# **12) Movies per year**

# %%
movies_per_year = df1['Year'].value_counts()
print(movies_per_year)
# Out:
# Year
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: count, dtype: int64

# %% [markdown]
# **13) Movies with rating > 8 & revenue > 100M**

# %%
df1[(df1['Rating'] > 8) & (df1['Revenue (Millions)'] > 100)][["Movie_Title","Rating","Revenue (Millions)"]]
# Out:
#                                       Movie_Title  Rating  Revenue (Millions)
# 0                         Guardians of the Galaxy     8.1              333.13
# 6                                      La La Land     8.3              151.06
# 36                                   Interstellar     8.6              187.99
# 50     Star Wars: Episode VII - The Force Awakens     8.1              936.63
# 54                                The Dark Knight     9.0              533.32
# 67                             Mad Max: Fury Road     8.1              153.63
# 74                                       Zootopia     8.1              341.26
# 76                                   The Avengers     8.1              623.28
# 77                           Inglourious Basterds     8.3              120.52
# 80                                      Inception     8.8              292.57
# 82                        The Wolf of Wall Street     8.2              116.87
# ...

# %% [markdown]
# 14) **Group by Director: avg Rating, Revenue**

# %%
df1.groupby('Director')[['Rating', 'Revenue (Millions)']].mean()
# Out:
#                      Rating  Revenue (Millions)
# Director
# Aamir Khan             8.50               1.200
# Abdellatif Kechiche    7.80               2.200
# Adam Leon              6.50                 NaN
# Adam McKay             7.00             109.535
# Adam Shankman          6.30              78.665
# ...                     ...                 ...
# Xavier Dolan           7.55               3.490
# Yimou Zhang            6.10              45.130
# Yorgos Lanthimos       7.20               4.405
# Zack Snyder            7.04             195.148
# Zackary Adler          5.10               6.530
#
# [644 rows x 2 columns]

# %% [markdown]
# **15) Group by Year: count, avg Rating**

# %%
year_status = df1.groupby("Year").agg(
    movie_count=("Movie_Title", "count"),
    avg_rating=("Rating", "mean")
)

year_status
# Out:
#       movie_count  avg_rating
# Year
# 2006           44    7.125000
# 2007           53    7.133962
# 2008           52    6.784615
# 2009           51    6.960784
# 2010           60    6.826667
# 2011           63    6.838095
# 2012           64    6.925000
# 2013           91    6.812088
# 2014           98    6.837755
# 2015          127    6.602362
# 2016          297    6.436700

# %% [markdown]
# 16) Create a new column Profitability:
# a) Revenue divided by Duration
# b) Find top 10 most profitable movies

# %%
df1['Profitability'] = df1['Revenue (Millions)'] / df1['Runtime (Minutes)']
top_10=df1.nlargest(10,"Profitability")
top_10[["Movie_Title","Revenue (Millions)","Runtime (Minutes)","Profitability"]]
# Out:
#                                     Movie_Title  Revenue (Millions)  \
# 50   Star Wars: Episode VII - The Force Awakens              936.63
# 85                               Jurassic World              652.18
# 119                                Finding Dory              486.29
# 87                                       Avatar              760.51
# 76                                 The Avengers              623.28
# 15                      The Secret Life of Pets              368.31
# 688                                 Toy Story 3              414.98
# 12                                    Rogue One              532.17
# 174                                      Frozen              400.74
# 797                             Despicable Me 2              368.05
#
#      Runtime (Minutes)  Profitability
# 50                 136       6.886985
# 85                 124       5.259516
# 119                 97       5.013299
# 87                 162       4.694506
# ...

# %% [markdown]
# 17) Create a column that categorizes movies by rating:
# a) Rating < 6: Poor
# b) 6 ≤ Rating < 7.5: Average
# c) Rating ≥ 7.5: Excellent

# %%
df1["Rating_Summary"]=df1["Rating"].apply(lambda x: 'Poor' if x < 6 else ('Average' if x < 7.5 else 'Excellent'))
df1[['Movie_Title', 'Rating', 'Rating_Summary']]
# Out:
#                  Movie_Title  Rating Rating_Summary
# 0    Guardians of the Galaxy     8.1      Excellent
# 1                 Prometheus     7.0        Average
# 2                      Split     7.3        Average
# 3                       Sing     7.2        Average
# 4              Suicide Squad     6.2        Average
# ..                       ...     ...            ...
# 995     Secret in Their Eyes     6.2        Average
# 996          Hostel: Part II     5.5           Poor
# 997   Step Up 2: The Streets     6.2        Average
# 998             Search Party     5.6           Poor
# 999               Nine Lives     5.3           Poor
#
# [1000 rows x 3 columns]

# %% [markdown]
# 18) Create a custom function to score movies based on:
# i) Apply row['Rating'] * 10 + row['Revenue (Millions)'] as High score
# Apply a function to dataset to assign the score

# %%
df1['High_Score'] = df1.apply(lambda row: row['Rating'] * 10 + row['Revenue (Millions)'], axis=1)
df1[['Movie_Title', 'Rating', 'Revenue (Millions)', 'High_Score']]
# Out:
#                  Movie_Title  Rating  Revenue (Millions)  High_Score
# 0    Guardians of the Galaxy     8.1              333.13      414.13
# 1                 Prometheus     7.0              126.46      196.46
# 2                      Split     7.3              138.12      211.12
# 3                       Sing     7.2              270.32      342.32
# 4              Suicide Squad     6.2              325.02      387.02
# ..                       ...     ...                 ...         ...
# 995     Secret in Their Eyes     6.2                 NaN         NaN
# 996          Hostel: Part II     5.5               17.54       72.54
# 997   Step Up 2: The Streets     6.2               58.01      120.01
# 998             Search Party     5.6                 NaN         NaN
# 999               Nine Lives     5.3               19.64       72.64
#
# [1000 rows x 4 columns]
