# %% [markdown]
# <a href="https://colab.research.google.com/github/sreehariar04/python_practice/blob/main/Practice3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PRACTICE EXERCISES ON PYTHON BASICS**

# %% [markdown]
# 1.Write a Python program which accepts the radius of a circle from the user and compute the area.

# %%
import math
radius = float(input('Enter Radius of circle: '))
area = math.pi*radius*radius

print(f'Area of circle is {area:.2f}')
# Out:
# Enter Radius of circle: 3
# Area of circle is 28.27

# %% [markdown]
# 2. Write a Python Program to accept the details of a student like name, roll
# number and mark and display it.
# Sample input: Enter the name: Anisha
# Enter the roll number: 21
# Enter the mark: 78
# Sample output: Name: Anisha
# Roll No: 21
# Mark: 78

# %%
name =input('Enter the name: ')
roll_no = input('Enter the roll number: ')
marks = input('Enter the marks: ')

print('Name:',name)
print('Roll No:',roll_no)
print('Marks:',marks)
# Out:
# Enter the name: Sreehari
# Enter the roll number: 34
# Enter the marks: 78
# Name: Sreehari
# Roll No: 34
# Marks: 78

# %% [markdown]
# 3. Write a Python program to get the largest number from a list.
# Sample input: 12, 3, 47, 10
# Sample output: 47 is the largest number.

# %%
numbers = input('Enter numbers (use comma to separate): ').split(',')

for i in range(len(numbers)):
    numbers[i] = int(numbers[i])

print(f'{max(numbers)} is the largest number')
# Out:
# Enter numbers (use comma to separate): 12,3,47,10
# 47 is the largest number

# %% [markdown]
# 4.Given a range of first 10 numbers, write a Python program to iterate from start number to the end number and print the sum of the current number and previous number.

# %%
prev = 0

for current in range (1,11):
  sum = current +prev
  print(f'Current Number {current} Previous Number {prev} Sum: {sum}')
  prev = current
# Out:
# Current Number 1 Previous Number 0 Sum: 1
# Current Number 2 Previous Number 1 Sum: 3
# Current Number 3 Previous Number 2 Sum: 5
# Current Number 4 Previous Number 3 Sum: 7
# Current Number 5 Previous Number 4 Sum: 9
# Current Number 6 Previous Number 5 Sum: 11
# Current Number 7 Previous Number 6 Sum: 13
# Current Number 8 Previous Number 7 Sum: 15
# Current Number 9 Previous Number 8 Sum: 17
# Current Number 10 Previous Number 9 Sum: 19

# %% [markdown]
# 5. Write a Python program to print only those numbers which are divisible of 5.
# Sample input: 10, 20,33,46,55 Sample output: 10, 20, 55

# %%
num = input ('Enter numbers: ').split(',')
divisible_by_5 =[]

for n in num:
  n=int(n)
  if n%5==0:
   divisible_by_5.append(str(n))
print(','.join(divisible_by_5))
# Out:
# Enter numbers: 10,33,20,46,55
# 10,20,55

# %% [markdown]
# 6. Write a Python program to check whether a number is prime or not. Sample input: Enter the number: 3
# Sample output: 3 is a prime number.

# %%
num = int(input('Enter a number: '))

if num>1:
  for i in range (2,int(num**0.5)+1):
    if num%i==0:
      print(num,'is not a prime number')
      break
  else:
      print(num,'is a prime number')
else:
  print(num,'is not a prime number')
# Out:
# Enter a number: 3
# 3 is a prime number

# %% [markdown]
# 7. Write a Python program to reverse a list using for loop.
# Sample input: 10,40,30,70
# Sample output: 70,30,40,10

# %%
#DONT KNOW

# %% [markdown]
# 8. Write a Python program to print the following pattern.

# %%
rows= 4

for i in range(1,rows+1):
 print('*'*i)
# Out:
# *
# **
# ***
# ****

# %% [markdown]
# 9. Write a Python program to find the maximum of three numbers
# Sample input: 34,12,7
# Sample output: 34

# %%
num = input('enter the list of numbers: ').split(',')

for i in range(len(num)):
   num[i]=int(num[i])

print(max(num))
# Out:
# enter the list of numbers: 34,12,7
# 34

# %% [markdown]
# 10. Write a Python program to construct the following pattern, using a nested for loop.

# %%
#Dont know
